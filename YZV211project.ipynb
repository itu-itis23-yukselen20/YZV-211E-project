# %%
import pandas as pd

df_industry_index = pd.read_excel("cpi.xlsx")
display(df_industry_index.head(10))
# Out:
#      Tarih Consumer Price Index (2003=100)(Monthly) Unnamed: 2
# 0  2003-01                                    94.77        NaN
# 1  2003-02                                    96.23        NaN
# 2  2003-03                                    98.12        NaN
# 3  2003-04                                    99.09        NaN
# 4  2003-05                                   100.04        NaN
# 5  2003-06                                   100.12        NaN
# 6  2003-07                                    99.93        NaN
# 7  2003-08                                   100.09        NaN
# 8  2003-09                                   101.44        NaN
# 9  2003-10                                   102.38        NaN

# %%
df_industry_index = pd.read_excel("econgrowth.xls")
display(df_industry_index.head(20))
# Out:
#    Mevsim etkisinden arındırılmış cari fiyatlarla gelir yöntemiyle gayrisafi yurt içi hasıla değeri ve değişim oranları, III. Çeyrek: Temmuz-Eylül, 2023  \
# 0   Seasonally adjusted at current prices by incom...
# 1         İşgücü ödemeleri\nCompensation of employees
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6      Gayrisafi yurt içi hasıla (alıcı fiyatlarıyla)
# 7          Gross domestic product (purchaser's price)
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# ...

# %%
df_industry_index = pd.read_excel("gdp.xlsx")
display(df_industry_index.head(10))
# Out:
#      Tarih              GDP Unnamed: 2
# 0  1998-Q1  13449124.934991        NaN
# 1  1998-Q2  16467818.909404        NaN
# 2  1998-Q3  20735679.122822        NaN
# 3  1998-Q4  21292076.644628        NaN
# 4  1999-Q1  19500039.431662        NaN
# 5  1999-Q2  24544171.872837        NaN
# 6  1999-Q3  30184139.943801        NaN
# 7  1999-Q4  33145906.701268        NaN
# 8  2000-Q1  33421822.215485        NaN
# 9  2000-Q2  40505292.492512        NaN
